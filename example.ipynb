# %% [markdown]
# # Pandas Highcharts Example

# %% [markdown]
# * Use [Highcharts](http://highcharts.com) to plot [pandas](http://pandas.pydata.org) DataFrame
# * Code on Github at [pandas-highcharts](https://github.com/gtnx/pandas-highcharts)

# %% [markdown]
# ## Import

# %%
import pandas as pd
import datetime
from urllib2 import urlopen
from IPython.display import display, display_pretty, Javascript, HTML
from pandas_highcharts.core import serialize
from pandas_highcharts.display import display_charts

df = pd.read_csv(
    urlopen('http://www.quandl.com/api/v1/datasets/ODA/DEU_PCPIPCH.csv?column=1'),
    index_col=0, parse_dates=True
)

# %% [markdown]
# ## Use the display_charts function

# %%
display_charts(df, title="Germany inflation rate")
# Out:
# <div id="chart_iduPRbhkGB"</div>
#     <script type="text/javascript">new Highcharts.Chart({"title":{"text":"Germany inflation rate"},"series":[{"data":[[347068800000,5.447],[378604800000,6.324],[410140800000,5.256],[441676800000,3.284],[473299200000,2.396],[504835200000,2.084],[536371200000,-0.125],[567907200000,0.242],[599529600000,1.274],[631065600000,2.778],[662601600000,2.687],[694137600000,3.474],[725760000000,5.046],[757296000000,4.476],[788832000000,2.717],[820368000000,1.733],[851990400000,1.19],[883526400000,1.542],[915062400000,0.593],[946598400000,0.626],[978220800000,1.418],[1009756800000,1.904],[1041292800000,1.346],[1072828800000,1.022],[1104451200000,1.799],[1135987200000,1.92],[1167523200000,1.784],[1199059200000,2.285],[1230681600000,2.738],[1262217600000,0.226],[1293753600000,1.158],[1325289600000,2.498],[1356912000000,2.13],[1388448000000,1.601],[1419984000000,0.896],[1451520000000,1.247],[1483142400000,1.5],[1514678400000,1.7],[1546214400000,1.7],[1577750400000,1.7]],"name":"Value","yAxis":0}],"yAxis":[{}],"chart":{"renderTo":"chart_iduPRbhkGB"},"xAxis":{"type":"datetime","title":{"text":"Date"}},"legend":{"enabled":true}});</script>

# %%
display_charts(df, chart_type="stock", title="Germany inflation rate")
# Out:
# <div id="chart_idKndSsLsO"</div>
#     <script type="text/javascript">new Highcharts.StockChart({"title":{"text":"Germany inflation rate"},"series":[{"data":[[347068800000,5.447],[378604800000,6.324],[410140800000,5.256],[441676800000,3.284],[473299200000,2.396],[504835200000,2.084],[536371200000,-0.125],[567907200000,0.242],[599529600000,1.274],[631065600000,2.778],[662601600000,2.687],[694137600000,3.474],[725760000000,5.046],[757296000000,4.476],[788832000000,2.717],[820368000000,1.733],[851990400000,1.19],[883526400000,1.542],[915062400000,0.593],[946598400000,0.626],[978220800000,1.418],[1009756800000,1.904],[1041292800000,1.346],[1072828800000,1.022],[1104451200000,1.799],[1135987200000,1.92],[1167523200000,1.784],[1199059200000,2.285],[1230681600000,2.738],[1262217600000,0.226],[1293753600000,1.158],[1325289600000,2.498],[1356912000000,2.13],[1388448000000,1.601],[1419984000000,0.896],[1451520000000,1.247],[1483142400000,1.5],[1514678400000,1.7],[1546214400000,1.7],[1577750400000,1.7]],"name":"Value","yAxis":0}],"yAxis":[{}],"chart":{"renderTo":"chart_idKndSsLsO"},"xAxis":{"type":"datetime","title":{"text":"Date"}},"legend":{"enabled":true}});</script>

# %%
display_charts(df, kind="bar", title="Germany inflation rate")
# Out:
# <div id="chart_idUWKEmSXL"</div>
#     <script type="text/javascript">new Highcharts.Chart({"title":{"text":"Germany inflation rate"},"series":[{"data":[[347068800000,5.447],[378604800000,6.324],[410140800000,5.256],[441676800000,3.284],[473299200000,2.396],[504835200000,2.084],[536371200000,-0.125],[567907200000,0.242],[599529600000,1.274],[631065600000,2.778],[662601600000,2.687],[694137600000,3.474],[725760000000,5.046],[757296000000,4.476],[788832000000,2.717],[820368000000,1.733],[851990400000,1.19],[883526400000,1.542],[915062400000,0.593],[946598400000,0.626],[978220800000,1.418],[1009756800000,1.904],[1041292800000,1.346],[1072828800000,1.022],[1104451200000,1.799],[1135987200000,1.92],[1167523200000,1.784],[1199059200000,2.285],[1230681600000,2.738],[1262217600000,0.226],[1293753600000,1.158],[1325289600000,2.498],[1356912000000,2.13],[1388448000000,1.601],[1419984000000,0.896],[1451520000000,1.247],[1483142400000,1.5],[1514678400000,1.7],[1546214400000,1.7],[1577750400000,1.7]],"name":"Value","yAxis":0}],"yAxis":[{}],"chart":{"renderTo":"chart_idUWKEmSXL","type":"column"},"xAxis":{"type":"datetime","title":{"text":"Date"}},"legend":{"enabled":true}});</script>

# %%
display_charts(df, kind="barh", title="Germany inflation rate")
# Out:
# <div id="chart_iduiHzvCgC"</div>
#     <script type="text/javascript">new Highcharts.Chart({"title":{"text":"Germany inflation rate"},"series":[{"data":[[347068800000,5.447],[378604800000,6.324],[410140800000,5.256],[441676800000,3.284],[473299200000,2.396],[504835200000,2.084],[536371200000,-0.125],[567907200000,0.242],[599529600000,1.274],[631065600000,2.778],[662601600000,2.687],[694137600000,3.474],[725760000000,5.046],[757296000000,4.476],[788832000000,2.717],[820368000000,1.733],[851990400000,1.19],[883526400000,1.542],[915062400000,0.593],[946598400000,0.626],[978220800000,1.418],[1009756800000,1.904],[1041292800000,1.346],[1072828800000,1.022],[1104451200000,1.799],[1135987200000,1.92],[1167523200000,1.784],[1199059200000,2.285],[1230681600000,2.738],[1262217600000,0.226],[1293753600000,1.158],[1325289600000,2.498],[1356912000000,2.13],[1388448000000,1.601],[1419984000000,0.896],[1451520000000,1.247],[1483142400000,1.5],[1514678400000,1.7],[1546214400000,1.7],[1577750400000,1.7]],"name":"Value","yAxis":0}],"yAxis":[{}],"chart":{"renderTo":"chart_iduiHzvCgC","type":"bar"},"xAxis":{"type":"datetime","title":{"text":"Date"}},"legend":{"enabled":true}});</script>

# %%
display_charts(df, title="Germany inflation rate", legend=None, kind="bar", figsize = (400, 200))
# Out:
# <div id="chart_idWZxAjQNV"</div>
#     <script type="text/javascript">new Highcharts.Chart({"title":{"text":"Germany inflation rate"},"series":[{"data":[[347068800000,5.447],[378604800000,6.324],[410140800000,5.256],[441676800000,3.284],[473299200000,2.396],[504835200000,2.084],[536371200000,-0.125],[567907200000,0.242],[599529600000,1.274],[631065600000,2.778],[662601600000,2.687],[694137600000,3.474],[725760000000,5.046],[757296000000,4.476],[788832000000,2.717],[820368000000,1.733],[851990400000,1.19],[883526400000,1.542],[915062400000,0.593],[946598400000,0.626],[978220800000,1.418],[1009756800000,1.904],[1041292800000,1.346],[1072828800000,1.022],[1104451200000,1.799],[1135987200000,1.92],[1167523200000,1.784],[1199059200000,2.285],[1230681600000,2.738],[1262217600000,0.226],[1293753600000,1.158],[1325289600000,2.498],[1356912000000,2.13],[1388448000000,1.601],[1419984000000,0.896],[1451520000000,1.247],[1483142400000,1.5],[1514678400000,1.7],[1546214400000,1.7],[1577750400000,1.7]],"name":"Value","yAxis":0}],"yAxis":[{}],"chart":{"width":400,"renderTo":"chart_idWZxAjQNV","type":"column","height":200},"xAxis":{"type":"datetime","title":{"text":"Date"}},"legend":{"enabled":null}});</script>

# %%
display_charts(df, title="Germany inflation rate", kind="bar", render_to="chart5", zoom="xy")
# Out:
# <div id="chart5"</div>
#     <script type="text/javascript">new Highcharts.Chart({"title":{"text":"Germany inflation rate"},"series":[{"data":[[347068800000,5.447],[378604800000,6.324],[410140800000,5.256],[441676800000,3.284],[473299200000,2.396],[504835200000,2.084],[536371200000,-0.125],[567907200000,0.242],[599529600000,1.274],[631065600000,2.778],[662601600000,2.687],[694137600000,3.474],[725760000000,5.046],[757296000000,4.476],[788832000000,2.717],[820368000000,1.733],[851990400000,1.19],[883526400000,1.542],[915062400000,0.593],[946598400000,0.626],[978220800000,1.418],[1009756800000,1.904],[1041292800000,1.346],[1072828800000,1.022],[1104451200000,1.799],[1135987200000,1.92],[1167523200000,1.784],[1199059200000,2.285],[1230681600000,2.738],[1262217600000,0.226],[1293753600000,1.158],[1325289600000,2.498],[1356912000000,2.13],[1388448000000,1.601],[1419984000000,0.896],[1451520000000,1.247],[1483142400000,1.5],[1514678400000,1.7],[1546214400000,1.7],[1577750400000,1.7]],"name":"Value","yAxis":0}],"yAxis":[{}],"chart":{"zoomType":"xy","renderTo":"chart5","type":"column"},"xAxis":{"type":"datetime","title":{"text":"Date"}},"legend":{"enabled":true}});</script>

# %%
df2 = pd.DataFrame([
    {"a": 1, "b": 2, "c": 3, "t": datetime.datetime(2015, 1, 1, 0)},
    {"a": 2, "b": 4, "c": 6, "t": datetime.datetime(2015, 1, 1, 1)}
])
display_charts(df2, x="t", y=["a", "c"], kind="bar")
# Out:
# <div id="chart_idCbaQwYkk"</div>
#     <script type="text/javascript">new Highcharts.Chart({"series":[{"data":[[1420070400000,1],[1420074000000,2]],"name":"a","yAxis":0},{"data":[[1420070400000,3],[1420074000000,6]],"name":"c","yAxis":0}],"yAxis":[{}],"chart":{"renderTo":"chart_idCbaQwYkk","type":"column"},"xAxis":{"type":"datetime","title":{"text":"t"}},"legend":{"enabled":true}});</script>

# %% [markdown]
# ## Get Serialized Data an Plot with the IPython Display Feature

# %%
data = serialize(df, render_to="chart1", kind="barh", output_type="json")

# %%
data.keys()
# Out:
# ['series', 'yAxis', 'chart', 'xAxis', 'legend']

# %%
data
# Out:
# {'chart': {'renderTo': 'chart1', 'type': 'bar'},
#  'legend': {'enabled': True},
#  'series': [{'data': [(0, 1), (1, 2)], 'name': 'a', 'yAxis': 0},
#   {'data': [(0, 3), (1, 6)], 'name': 'c', 'yAxis': 0},
#   {'data': [(0, 2), (1, 4)], 'name': 'b', 'yAxis': 0}],
#  'xAxis': {},
#  'yAxis': [{}]}

# %%
js_data = serialize(df, render_to="chart1", kind="barh")

# %% [markdown]
# Use the display HTML IPython feature.

# %%
display(HTML("""
<div id="chart1"></div>
<script type="text/javascript">%(js_data)s</script>
""" % locals()))
# Out:
# <div id="chart1"></div>
# <script type="text/javascript">new Highcharts.Chart({"series":[{"data":[[0,1],[1,2]],"name":"a","yAxis":0},{"data":[[0,3],[1,6]],"name":"c","yAxis":0},{"data":[[0,2],[1,4]],"name":"b","yAxis":0}],"yAxis":[{}],"chart":{"renderTo":"chart1","type":"bar"},"xAxis":{},"legend":{"enabled":true}});</script>
